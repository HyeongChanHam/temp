# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # get data distribution polynomial

# %%
# object = (weight(Ton), length(meter))
person = (0.05, 0.44)
bicycle = (0.06, 1.8)
v1 = (0.78, 3.49)
v2 = (1.33, 4.65)
v3 = (1.4, 4.56)
v4 = (2.17, 5.11)
v5 = (15., 7.68)
v6 = (5., 5.9)
v7 = (3.5, 4.2)
v8 = (7., 6.2)
v9 = (13., 9.7)
v10 = (5.5, 2.5)
obj_list = [person, bicycle, v1, v2, v3, v4, v10, v8]#, v6,v7,v8, v9]
x = np.array([obj[0] for obj in obj_list])
y = np.array([obj[1] for obj in obj_list])
poly = 3
uncertain_z = np.polyfit(x,y,poly)
plt.scatter(x,y, label='dataset 1')

obj_list = [person, bicycle, v1, v2, v3, v4, v5, v6, v7, v8, v9, v10]
x = np.array([obj[0] for obj in obj_list])
y = np.array([obj[1] for obj in obj_list])
certain_z = np.polyfit(x,y,poly)
plt.scatter(x,y, marker='x', label='dataset 2')
print(z)
x_test = np.linspace(0,20,100)
# pred = z[0]*x_test**3 + z[1]*x_test**2 + z[2] * x_test + z[3]
pred = np.zeros_like(x_test)
for p in range(poly+1):
    print(p)
    pred += uncertain_z[p]*x_test**(poly-p)
# plt.plot(x_test, pred, color='blue', label='uncertain')

pred = np.zeros_like(x_test)

for p in range(poly+1):
    print(p)
    pred += certain_z[p]*x_test**(poly-p)
# plt.scatter(x,y)
# plt.plot(x_test, pred, color='orange', label='certain')
plt.legend()
plt.ylim(0,10)
plt.show()
# Out:
# [ 0.1607329  -1.70876333  4.85269108  0.80884279]
# 0
# 1
# 2
# 3
# 0
# 1
# 2
# 3

# %%
# object = (weight(Ton), length(meter))
person = (0.05, 0.44)
bicycle = (0.06, 1.8)
v1 = (0.78, 3.49)
v2 = (1.33, 4.65)
v3 = (1.4, 4.56)
v4 = (2.17, 5.11)
v5 = (15., 7.68)
v6 = (5., 5.9)
v7 = (3.5, 4.2)
v8 = (7., 6.2)
v9 = (13., 9.7)
v10 = (5.5, 2.5)
obj_list = [person, bicycle, v1, v2, v3, v4, v10, v8]#, v6,v7,v8, v9]
x = np.array([obj[0] for obj in obj_list])
y = np.array([obj[1] for obj in obj_list])
poly = 3
uncertain_z = np.polyfit(x,y,poly)

obj_list = [person, bicycle, v1, v2, v3, v4, v5, v6, v7, v8, v9, v10]
x = np.array([obj[0] for obj in obj_list])
y = np.array([obj[1] for obj in obj_list])
certain_z = np.polyfit(x,y,poly)
print(z)
x_test = np.linspace(0,20,100)
# pred = z[0]*x_test**3 + z[1]*x_test**2 + z[2] * x_test + z[3]
pred = np.zeros_like(x_test)
for p in range(poly+1):
    print(p)
    pred += uncertain_z[p]*x_test**(poly-p)
plt.scatter(x,y)
plt.plot(x_test, pred, color='blue', label='model 1')

pred = np.zeros_like(x_test)

for p in range(poly+1):
    print(p)
    pred += certain_z[p]*x_test**(poly-p)
plt.scatter(x,y)
plt.plot(x_test, pred, color='orange', label='model 2')
plt.legend()
plt.ylim(0,10)
plt.show()
# Out:
# [ 0.1607329  -1.70876333  4.85269108  0.80884279]
# 0
# 1
# 2
# 3
# 0
# 1
# 2
# 3

# %%
# object = (weight(Ton), length(meter))
person = (0.05, 0.44)
bicycle = (0.06, 1.8)
v1 = (0.78, 3.49)
v2 = (1.33, 4.65)
v3 = (1.4, 4.56)
v4 = (2.17, 5.11)
v5 = (15., 7.68)
v6 = (5., 5.9)
v7 = (3.5, 4.2)
v8 = (7., 6.2)
v9 = (13., 9.7)
v10 = (5.5, 2.5)
obj_list = [person, bicycle, v1, v2, v3, v4, v10, v8]#, v6,v7,v8, v9]
x = np.array([obj[0] for obj in obj_list])
y = np.array([obj[1] for obj in obj_list])
poly = 3
uncertain_z = np.polyfit(x,y,poly)

obj_list = [person, bicycle, v1, v2, v3, v4, v5, v6, v7, v8, v9, v10]
x = np.array([obj[0] for obj in obj_list])
y = np.array([obj[1] for obj in obj_list])
certain_z = np.polyfit(x,y,poly)
print(z)
x_test = np.linspace(0,20,100)
# pred = z[0]*x_test**3 + z[1]*x_test**2 + z[2] * x_test + z[3]
pred = np.zeros_like(x_test)
for p in range(poly+1):
    print(p)
    pred += uncertain_z[p]*x_test**(poly-p)
plt.scatter(x,y)
plt.plot(x_test, pred, color='blue', label='model 1')

pred = np.zeros_like(x_test)

for p in range(poly+1):
    print(p)
    pred += certain_z[p]*x_test**(poly-p)
plt.scatter(x,y)
plt.plot(x_test, pred, color='orange', label='model 2')
plt.legend()
plt.show()
# Out:
# [ 0.1607329  -1.70876333  4.85269108  0.80884279]
# 0
# 1
# 2
# 3
# 0
# 1
# 2
# 3

# %%
# !pwd
# !export PYTHONPATH=$PYTHONPATH:$(pwd)/evidential-learning-pytorch
import sys
print(sys.path)
sys.path.append('/work/DRO-EDL/1d/evidential-learning-pytorch')
# Out:
# /work/DRO-EDL/1d
# ['/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/home/opencda/.local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages']

# %%
from tqdm import tqdm
import torch
from torch import nn
from edl_pytorch import NormalInvGamma, evidential_regression
from torch.utils.data import DataLoader, TensorDataset

# %%
model = nn.Sequential(
    nn.Linear(1, 16),  # one input dim
    nn.ReLU(),
    NormalInvGamma(16, 1),  # one target variable
)

x = torch.randn(1, 1)  # (batch, dim)
y = torch.randn(1, 1)

pred_nig = model(x)  # (mu, v, alpha, beta)

loss = evidential_regression(
    pred_nig,      # predicted Normal Inverse Gamma parameters
    y,             # target labels
    lamb=0.001,    # regularization coefficient 
)

# %%
z
# Out:
# array([  565.21184393, -2531.44279717,  3622.22450946, -1204.42773054])

# %%
num_train_samples = 1000
# weight = np.random.normal(700, 1500,size=num_train_samples)# / 2200
# weight /= 2200
x_train = torch.linspace(0.05, 2.7,1000).unsqueeze(-1)
# length = 0.178 * weight**3 + 0.89 + np.random.uniform(-0.01,0.01, size=num_train_samples)
#length = (weight-1500)**3 * 0.00106 + 2.75 + np.random.uniform(-0.01,0.01, size=num_train_samples)
# length /= 5
# x_train = torch.tensor(weight, dtype=torch.float32)[None].T

sigma = torch.normal(torch.zeros_like(x_train), 3 * torch.ones_like(x_train))
# y_train = x_train**3 * 5.795 + 451.214 + sigma
y_train = z[0] * x_train ** 3 + z[1] * x_train ** 2 + z[2] * x_train + z[3] + sigma
print(x_train.shape, y_train.shape)
# print(x_train.shape)

# y_train = torch.tensor(length, dtype=torch.float32)[None].T

num_test_samples = 1000
# weight = np.random.uniform(100, 3000,size=num_train_samples)
# length = weight * 0.00106 + 2.75 + np.random.normal(-0.01,0.01, size=num_train_samples)
# weight /= 2200
# length /= 5
# x_test = torch.tensor(weight, dtype=torch.float32)[None].T
# y_test = torch.tensor(length, dtype=torch.float32)[None].T

x_test = torch.linspace(0, 3, num_test_samples).unsqueeze(-1)
# x_test /= 2200
# y_test = x_test**3 * 5.795 + 451.214
y_test = z[0] * x_test ** 3 + z[1] * x_test ** 2 + z[2] * x_test + z[3]
# Out:
# torch.Size([1000, 1]) torch.Size([1000, 1])

# %%
x_train = torch.linspace(-4, 4, 1000).unsqueeze(-1)
sigma = torch.normal(torch.zeros_like(x_train), 3 * torch.ones_like(x_train))
y_train = x_train**3 + sigma
print(x_train.shape, y_train.shape)
print(y_train.max())
x_test = torch.linspace(-7, 7, 1000).unsqueeze(-1)
y_test = x_test**3
# x_test /= x_train.max()
# y_test /= y_train.max()

# x_train /= x_train.max()
# y_train /= y_train.max()
print(y_test.max(), y_train.max())
# Out:
# torch.Size([1000, 1]) torch.Size([1000, 1])
# tensor(69.5642)
# tensor(343.) tensor(69.5642)

# %%
plt.scatter(x_test,y_test)
plt.scatter(x_train, y_train)

# %%
plt.scatter(x_train, y_train)
plt.scatter(x_test,y_test)

# %%
plt.scatter(x_test,y_test)
plt.scatter(x_train, y_train)

# %% [markdown]
# # Train uncertain model

# %%
x_train = torch.linspace(1, 7, 1000).unsqueeze(-1)
sigma = torch.normal(torch.zeros_like(x_train), 0.1 * torch.ones_like(x_train))
y_train = uncertain_z[0] * x_train ** 3 + uncertain_z[1] * x_train ** 2 + uncertain_z[2] * x_train + uncertain_z[3] + sigma


x_test = torch.linspace(-2, 17, 1000).unsqueeze(-1)
y_test = uncertain_z[0] * x_test ** 3 + uncertain_z[1] * x_test ** 2 + uncertain_z[2] * x_test + uncertain_z[3]

plt.scatter(x_test,y_test)
plt.scatter(x_train, y_train)
plt.ylim(0,10)
plt.show()

# %%
x_train = torch.linspace(0.05, 8, 1000).unsqueeze(-1)
sigma = torch.normal(torch.zeros_like(x_train), 0.1 * torch.ones_like(x_train))
y_train = z[0] * x_train ** 2 + z[1] * x_train + z[2] + sigma


x_test = torch.linspace(-2, 17, 1000).unsqueeze(-1)
y_test = z[0] * x_test ** 2 + z[1] * x_test + z[2]

# %%
x_train = torch.linspace(1, 4, 1000).unsqueeze(-1)
sigma = torch.normal(torch.zeros_like(x_train), 1 * torch.ones_like(x_train))
y_train = z[0] * x_train + z[1] + sigma

x_test = torch.linspace(-2, 7, 1000).unsqueeze(-1)
y_test = z[0] * x_test + z[1]

# %%
loss_list = list()
test_loss_list = list()
uncertain_model = nn.Sequential(
    nn.Linear(1, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    NormalInvGamma(64, 1),
)

optimizer = torch.optim.Adam(uncertain_model.parameters(), lr=5e-4)

for epoch in tqdm(range(500)):
    for x, y in DataLoader(TensorDataset(x_train, y_train), batch_size=100, shuffle=True):
        pred = uncertain_model(x)
        # print(pred)
        loss = evidential_regression(pred, y, lamb=1e-2)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    loss_list.append(loss)
        
    with torch.no_grad():
        pred = uncertain_model(x_test)

    mu, v, alpha, beta = (d.squeeze() for d in pred)
    # if epoch % 100 == 0:
    #     print(mu[:10], v[:10], alpha[:10], beta[:10])
    # print(y_train[100:110][:,0])
    # print(mu[100:110])
    test_loss = torch.nn.MSELoss()(y_train[:,0], mu)
    test_loss_list.append(test_loss)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:04<00:00, 111.71it/s]

# %%
plt.plot([x.detach().numpy() for x in loss_list])
plt.plot([x.detach().numpy() for x in test_loss_list])
plt.show()

# %%
x_test = x_test[:,None]
with torch.no_grad():
    pred = uncertain_model(x_test)

mu, v, alpha, beta = (d.squeeze() for d in pred)
x_test = x_test.squeeze()

var = torch.sqrt(beta / (v * (alpha - 1 + np.finfo(float).eps)))

# %%
plt.figure(figsize=(5, 3), dpi=200)
plt.scatter(x_train, y_train, s=1.0, c="tab:red", label="Train")
plt.plot(x_test, y_test, c="k", label="True")
plt.plot(x_test, mu, c="tab:blue", ls="--", label="Pred")
for std in range(4):
    plt.fill_between(
        x_test.squeeze(),
        (mu - std * var),
        (mu + std * var),
        alpha=0.2,
        facecolor="tab:blue",
        label="Unc." if std == 0 else None,
    )
# plt.gca().set_ylim(-10, 50)
plt.gca().set_ylim(-10, 30)
# plt.gca().set_xlim(-10, 10)
plt.legend(loc="upper left")
plt.show()

# %%
x_train = torch.linspace(1, 15, 1000).unsqueeze(-1)
sigma = torch.normal(torch.zeros_like(x_train), 0.1 * torch.ones_like(x_train))
y_train = certain_z[0] * x_train ** 3 + certain_z[1] * x_train ** 2 + certain_z[2] * x_train + certain_z[3] + sigma


x_test = torch.linspace(-2, 17, 1000).unsqueeze(-1)
y_test = certain_z[0] * x_test ** 3 + certain_z[1] * x_test ** 2 + certain_z[2] * x_test + certain_z[3]

plt.scatter(x_test,y_test)
plt.scatter(x_train, y_train)
plt.ylim(0,10)
plt.show()

# %%
loss_list = list()
test_loss_list = list()
certain_model = nn.Sequential(
    nn.Linear(1, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    NormalInvGamma(64, 1),
)

optimizer = torch.optim.Adam(certain_model.parameters(), lr=5e-4)

for epoch in tqdm(range(100)):
    for x, y in DataLoader(TensorDataset(x_train, y_train), batch_size=100, shuffle=True):
        pred = certain_model(x)
        # print(pred)
        loss = evidential_regression(pred, y, lamb=1e-2)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    loss_list.append(loss)
        
    with torch.no_grad():
        pred = certain_model(x_test)

    mu, v, alpha, beta = (d.squeeze() for d in pred)
    # if epoch % 100 == 0:
    #     print(mu[:10], v[:10], alpha[:10], beta[:10])
    # print(y_train[100:110][:,0])
    # print(mu[100:110])
    test_loss = torch.nn.MSELoss()(y_train[:,0], mu)
    test_loss_list.append(test_loss)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 108.68it/s]

# %%
plt.plot([x.detach().numpy() for x in loss_list])
plt.plot([x.detach().numpy() for x in test_loss_list])
plt.show()

# %%
x_test = x_test[:,None]
with torch.no_grad():
    pred = certain_model(x_test)

mu, v, alpha, beta = (d.squeeze() for d in pred)
x_test = x_test.squeeze()

var = torch.sqrt(beta / (v * (alpha - 1 + np.finfo(float).eps)))

# %%
plt.figure(figsize=(5, 3), dpi=200)
plt.scatter(x_train, y_train, s=1.0, c="tab:red", label="Train")
plt.plot(x_test, y_test, c="k", label="True")
plt.plot(x_test, mu, c="tab:blue", ls="--", label="Pred")
for std in range(4):
    plt.fill_between(
        x_test.squeeze(),
        (mu - std * var),
        (mu + std * var),
        alpha=0.2,
        facecolor="tab:blue",
        label="Unc." if std == 0 else None,
    )
# plt.gca().set_ylim(-10, 50)
plt.gca().set_ylim(-10, 30)
# plt.gca().set_xlim(-10, 10)
plt.legend(loc="upper left")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, invgamma

# %%
data = [6.5]
for d in data:
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in uncertain_model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print(beta / ((alpha-1)*lambda_))
    # Define parameters for the Normal-Inverse Gamma distribution
    # mu_0 = 0  # Prior mean
    # lambda_ = 1  # Scale parameter
    # alpha = 2  # Shape parameter
    # beta = 2  # Scale parameter
    
    # Create a grid for mean (mu) and variance (sigma^2)
    mu = np.linspace(0, 20, 100)
    sigma2 = np.linspace(0., 1, 100)
    mu_grid, sigma2_grid = np.meshgrid(mu, sigma2)
    
    # Compute the probability density function values for the Normal-Inverse Gamma distribution
    pdf_values = np.zeros_like(mu_grid)
    
    for i in range(mu_grid.shape[0]):
        for j in range(mu_grid.shape[1]):
            mu_val = mu_grid[i, j]
            sigma2_val = sigma2_grid[i, j]
            # Normal-Inverse Gamma PDF (up to proportionality constant)
            # pdf_values[i, j] = (sigma2_val ** (-alpha - 1)) * np.exp(-beta / sigma2_val) * \
            #                    norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))
            pdf_values[i, j] = invgamma.pdf(sigma2_val, alpha, beta) * norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))

    
    # Plot the PDF values
    plt.figure(figsize=(10, 8))
    cp = plt.contourf(mu, sigma2, pdf_values, levels=50, cmap='viridis')
    plt.colorbar(cp)
    plt.xlabel('Mean (mu)')
    plt.ylabel('Variance (sigma^2)')
    plt.title('Normal-Inverse Gamma Distribution PDF')
    plt.show()
# Out:
# [3.4548569] [0.02503136] [4.8973227] [0.06900783]
# [0.70737135]

# %%
dist_colors = ['g', 'y']
for i,d in enumerate([6.5]):
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in uncertain_model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print("E[mu]: ",mu_0)
    print("Var[mu]: ",(beta / ((alpha-1)*lambda_)))
    print("E[sigma]: ",(beta / (alpha-1)))
    print("E[sigma] / lambda: ",(beta / (alpha-1)) / lambda_)
    
    num_dist_samples = 1000
    l = np.linspace(-20, 20, 100)
    mu_list = list()
    sigma_list = list()
    msv_list = list()
    for _ in range(num_dist_samples):
        sigma2_sample = invgamma.rvs(alpha, beta)
        mu_sample = norm.rvs(mu_0, np.sqrt(sigma2_sample / lambda_))
        msv_list.append(np.sqrt(sigma2_sample / lambda_))
        mu_list.append(mu_sample)
        sigma_list.append(sigma2_sample / lambda_)
        plt.plot(l, norm.pdf(l, mu_sample, sigma2_sample), alpha=0.1, color=dist_colors[i])
    print("diff min: ",max(mu_list) - min(mu_list))
    print(min(sigma_list), max(sigma_list))
    print("msv: ",np.array(msv_list).mean())
    plt.xlim(-25,25)
    plt.ylim(-0.1,4)
    print()
    
plt.show()
# Out:
# [3.4548569] [0.02503136] [4.8973227] [0.06900783]
# E[mu]:  [3.4548569]
# Var[mu]:  [0.70737135]
# E[sigma]:  [0.01770647]
# E[sigma] / lambda:  [0.7073714]
# diff min:  33.08946669158526
# [5.634296] [67.19871]
# msv:  3.5349908

# %%
data = [6.5]
for d in data:
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in certain_model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print(beta / ((alpha-1)*lambda_))
    # Define parameters for the Normal-Inverse Gamma distribution
    # mu_0 = 0  # Prior mean
    # lambda_ = 1  # Scale parameter
    # alpha = 2  # Shape parameter
    # beta = 2  # Scale parameter
    
    # Create a grid for mean (mu) and variance (sigma^2)
    mu = np.linspace(0, 20, 100)
    sigma2 = np.linspace(0., 1, 100)
    mu_grid, sigma2_grid = np.meshgrid(mu, sigma2)
    
    # Compute the probability density function values for the Normal-Inverse Gamma distribution
    pdf_values = np.zeros_like(mu_grid)
    
    for i in range(mu_grid.shape[0]):
        for j in range(mu_grid.shape[1]):
            mu_val = mu_grid[i, j]
            sigma2_val = sigma2_grid[i, j]
            # Normal-Inverse Gamma PDF (up to proportionality constant)
            # pdf_values[i, j] = (sigma2_val ** (-alpha - 1)) * np.exp(-beta / sigma2_val) * \
            #                    norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))
            pdf_values[i, j] = invgamma.pdf(sigma2_val, alpha, beta) * norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))

    
    # Plot the PDF values
    plt.figure(figsize=(10, 8))
    cp = plt.contourf(mu, sigma2, pdf_values, levels=50, cmap='viridis')
    plt.colorbar(cp)
    plt.xlabel('Mean (mu)')
    plt.ylabel('Variance (sigma^2)')
    plt.title('Normal-Inverse Gamma Distribution PDF')
    plt.show()
# Out:
# [5.920605] [0.88203037] [4.362318] [0.01417785]
# [0.00478066]
# /home/opencda/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %%
dist_colors = ['g', 'y']
for i,d in enumerate([6.5]):
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in certain_model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print("E[mu]: ",mu_0)
    print("Var[mu]: ",(beta / ((alpha-1)*lambda_)))
    print("E[sigma]: ",(beta / (alpha-1)))
    print("E[sigma] / lambda: ",(beta / (alpha-1)) / lambda_)
    
    num_dist_samples = 1000
    l = np.linspace(-20, 20, 100)
    mu_list = list()
    sigma_list = list()
    msv_list = list()
    for _ in range(num_dist_samples):
        sigma2_sample = invgamma.rvs(alpha, beta)
        mu_sample = norm.rvs(mu_0, np.sqrt(sigma2_sample / lambda_))
        msv_list.append(np.sqrt(sigma2_sample / lambda_))
        mu_list.append(mu_sample)
        sigma_list.append(sigma2_sample / lambda_)
        plt.plot(l, norm.pdf(l, mu_sample, sigma2_sample), alpha=0.1, color=dist_colors[i])
    print("diff min: ",max(mu_list) - min(mu_list))
    print(min(sigma_list), max(sigma_list))
    print("msv: ",np.array(msv_list).mean())
    plt.xlim(-25,25)
    plt.ylim(-0.1,4)
    print()
    
plt.show()
# Out:
# [5.920605] [0.88203037] [4.362318] [0.01417785]
# E[mu]:  [5.920605]
# Var[mu]:  [0.00478066]
# E[sigma]:  [0.00421669]
# E[sigma] / lambda:  [0.00478066]
# diff min:  5.451502665642425
# [0.09613237] [2.2275975]
# msv:  0.5762386

# %%
data = [6.1, 2.17]
for d in data:
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print(beta / ((alpha-1)*lambda_))
    # Define parameters for the Normal-Inverse Gamma distribution
    # mu_0 = 0  # Prior mean
    # lambda_ = 1  # Scale parameter
    # alpha = 2  # Shape parameter
    # beta = 2  # Scale parameter
    
    # Create a grid for mean (mu) and variance (sigma^2)
    mu = np.linspace(-4, 7, 100)
    sigma2 = np.linspace(0., 1, 100)
    mu_grid, sigma2_grid = np.meshgrid(mu, sigma2)
    
    # Compute the probability density function values for the Normal-Inverse Gamma distribution
    pdf_values = np.zeros_like(mu_grid)
    
    for i in range(mu_grid.shape[0]):
        for j in range(mu_grid.shape[1]):
            mu_val = mu_grid[i, j]
            sigma2_val = sigma2_grid[i, j]
            # Normal-Inverse Gamma PDF (up to proportionality constant)
            # pdf_values[i, j] = (sigma2_val ** (-alpha - 1)) * np.exp(-beta / sigma2_val) * \
            #                    norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))
            pdf_values[i, j] = invgamma.pdf(sigma2_val, alpha, beta) * norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))

    
    # Plot the PDF values
    plt.figure(figsize=(10, 8))
    cp = plt.contourf(mu, sigma2, pdf_values, levels=50, cmap='viridis')
    plt.colorbar(cp)
    plt.xlabel('Mean (mu)')
    plt.ylabel('Variance (sigma^2)')
    plt.title('Normal-Inverse Gamma Distribution PDF')
    plt.show()
# Out:
# [3.3069992] [0.09277739] [3.4838414] [0.03017405]
# [0.13093859]
# [4.9552536] [6.7182527] [5.0919623] [0.03772904]
# [0.00137242]

# %%
dist_colors = ['g', 'y']
for i,d in enumerate([6.1, 2.17]):
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print("E[mu]: ",mu_0)
    print("Var[mu]: ",(beta / ((alpha-1)*lambda_)))
    print("E[sigma]: ",(beta / (alpha-1)))
    print("E[sigma] / lambda: ",(beta / (alpha-1)) / lambda_)
    
    num_dist_samples = 1000
    l = np.linspace(-20, 20, 100)
    mu_list = list()
    sigma_list = list()
    msv_list = list()
    for _ in range(num_dist_samples):
        sigma2_sample = invgamma.rvs(alpha, beta)
        mu_sample = norm.rvs(mu_0, np.sqrt(sigma2_sample / lambda_))
        msv_list.append(np.sqrt(sigma2_sample / lambda_))
        mu_list.append(mu_sample)
        sigma_list.append(sigma2_sample / lambda_)
        plt.plot(l, norm.pdf(l, mu_sample, sigma2_sample), alpha=0.1, color=dist_colors[i])
    print("diff min: ",max(mu_list) - min(mu_list))
    print(min(sigma_list), max(sigma_list))
    print("msv: ",np.array(msv_list).mean())
    plt.xlim(-25,25)
    plt.ylim(-0.1,4)
    print()
    
plt.show()
# Out:
# [3.3069992] [0.09277739] [3.4838414] [0.03017405]
# E[mu]:  [3.3069992]
# Var[mu]:  [0.13093859]
# E[sigma]:  [0.01214814]
# E[sigma] / lambda:  [0.13093859]
# diff min:  18.52376735035262
# [1.1619911] [69.015396]
# msv:  2.0691228
#
# [4.9552536] [6.7182527] [5.0919623] [0.03772904]
# E[mu]:  [4.9552536]
# Var[mu]:  [0.00137242]
# E[sigma]:  [0.00922028]
# E[sigma] / lambda:  [0.00137242]
# diff min:  1.5367990690484001
# [0.0148061] [0.28226516]
# msv:  0.20188253

# %%
t_dist.std()
# Out:
# 0.6468275847007903

# %%
t(10000,2,3).std()
# Out:
# 3.0003000450075015

# %%
from scipy.stats import t
l = np.linspace(-20, 20, 100)
epsilon = 0.95

mu_0, lambda_, alpha, beta = 3.4548569, 0.02503136, 4.8973227, 0.06900783#3.3069992, 0.09277739, 3.4838414, 0.03017405
t_dist = t((2*alpha), mu_0, ((beta*(1+lambda_))/(lambda_*alpha))**(1/2))
plt.plot(l, t_dist.pdf(l), label='model 1')
nu = 2 * alpha
num_sample = nu + 1

st_cvar =         mu_0 + ((beta * (1+lambda_))/(lambda_*alpha))**(1/2) * ((2*alpha+t.ppf(epsilon, nu)**2)/((2*alpha-1)*(1-epsilon))) * t.pdf(t.ppf(epsilon, nu), nu)
plt.axvline(x=st_cvar, color='r', linestyle='--', label=f'model 1 CVaR (α={epsilon*100}%) = {st_cvar:.2f}')

plt.xlim(-20,20)
plt.legend()
plt.show()

# %%
mu_0, lambda_, alpha, beta = 5.920605, 0.88203037, 4.362318, 0.01417785#3.4548569, 0.02503136, 4.8973227, 0.06900783#3.3069992, 0.09277739, 3.4838414, 0.03017405
t_dist = t((2*alpha), mu_0, ((beta*(1+lambda_))/(lambda_*alpha)))
plt.plot(l, t_dist.pdf(l), label='model 2')
st_cvar = mu_0 + ((beta * (1+lambda_))/(lambda_*alpha))**(1/2) * ((2*alpha+t_dist.ppf(epsilon)**2)/(2*alpha-1)*(1-epsilon)) * t_dist.pdf(t_dist.ppf(epsilon))
print("std: ",((beta*(1+lambda_))/(lambda_*alpha))**(1/2))
plt.axvline(x=st_cvar, color='r', linestyle='--', label=f'model 2 CVaR (α={epsilon*100}%) = {st_cvar:.2f}')
plt.xlim(-20,20)
# ale = beta / ((alpha-1))
# norm_dist = norm(mu_0, ale)
# # plt.plot(l, norm_dist.pdf(l))
plt.legend()
plt.show()
# Out:
# std:  0.08327565785637121

# %% [markdown]
# # Certain Case

# %%
data = [3.]
for d in data:
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in uncertain_model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print(beta / ((alpha-1)*lambda_))
    # Define parameters for the Normal-Inverse Gamma distribution
    # mu_0 = 0  # Prior mean
    # lambda_ = 1  # Scale parameter
    # alpha = 2  # Shape parameter
    # beta = 2  # Scale parameter
    
    # Create a grid for mean (mu) and variance (sigma^2)
    mu = np.linspace(0, 20, 100)
    sigma2 = np.linspace(0., 1, 100)
    mu_grid, sigma2_grid = np.meshgrid(mu, sigma2)
    
    # Compute the probability density function values for the Normal-Inverse Gamma distribution
    pdf_values = np.zeros_like(mu_grid)
    
    for i in range(mu_grid.shape[0]):
        for j in range(mu_grid.shape[1]):
            mu_val = mu_grid[i, j]
            sigma2_val = sigma2_grid[i, j]
            # Normal-Inverse Gamma PDF (up to proportionality constant)
            # pdf_values[i, j] = (sigma2_val ** (-alpha - 1)) * np.exp(-beta / sigma2_val) * \
            #                    norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))
            pdf_values[i, j] = invgamma.pdf(sigma2_val, alpha, beta) * norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))

    
    # Plot the PDF values
    plt.figure(figsize=(10, 8))
    cp = plt.contourf(mu, sigma2, pdf_values, levels=50, cmap='viridis')
    plt.colorbar(cp)
    plt.xlabel('Mean (mu)')
    plt.ylabel('Variance (sigma^2)')
    plt.title('Normal-Inverse Gamma Distribution PDF')
    plt.show()
# Out:
# [4.331047] [10.395155] [5.679753] [0.06286594]
# [0.00129229]
# /home/opencda/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %%
dist_colors = ['g', 'y']
for i,d in enumerate([3.]):
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in uncertain_model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print("E[mu]: ",mu_0)
    print("Var[mu]: ",(beta / ((alpha-1)*lambda_)))
    print("E[sigma]: ",(beta / (alpha-1)))
    print("E[sigma] / lambda: ",(beta / (alpha-1)) / lambda_)
    
    num_dist_samples = 1000
    l = np.linspace(-20, 20, 100)
    mu_list = list()
    sigma_list = list()
    msv_list = list()
    for _ in range(num_dist_samples):
        sigma2_sample = invgamma.rvs(alpha, beta)
        mu_sample = norm.rvs(mu_0, np.sqrt(sigma2_sample / lambda_))
        msv_list.append(np.sqrt(sigma2_sample / lambda_))
        mu_list.append(mu_sample)
        sigma_list.append(sigma2_sample / lambda_)
        plt.plot(l, norm.pdf(l, mu_sample, sigma2_sample), alpha=0.1, color=dist_colors[i])
    print("diff min: ",max(mu_list) - min(mu_list))
    print(min(sigma_list), max(sigma_list))
    print("msv: ",np.array(msv_list).mean())
    plt.xlim(-25,25)
    plt.ylim(-0.1,4)
    print()
    
plt.show()
# Out:
# [4.331047] [10.395155] [5.679753] [0.06286594]
# E[mu]:  [4.331047]
# Var[mu]:  [0.00129229]
# E[sigma]:  [0.0134336]
# E[sigma] / lambda:  [0.00129229]
# diff min:  1.4653315493260912
# [0.01193909] [0.13548866]
# msv:  0.16112229

# %%
data = [3.]
for d in data:
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in certain_model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print(beta / ((alpha-1)*lambda_))
    # Define parameters for the Normal-Inverse Gamma distribution
    # mu_0 = 0  # Prior mean
    # lambda_ = 1  # Scale parameter
    # alpha = 2  # Shape parameter
    # beta = 2  # Scale parameter
    
    # Create a grid for mean (mu) and variance (sigma^2)
    mu = np.linspace(0, 20, 100)
    sigma2 = np.linspace(0., 1, 100)
    mu_grid, sigma2_grid = np.meshgrid(mu, sigma2)
    
    # Compute the probability density function values for the Normal-Inverse Gamma distribution
    pdf_values = np.zeros_like(mu_grid)
    
    for i in range(mu_grid.shape[0]):
        for j in range(mu_grid.shape[1]):
            mu_val = mu_grid[i, j]
            sigma2_val = sigma2_grid[i, j]
            # Normal-Inverse Gamma PDF (up to proportionality constant)
            # pdf_values[i, j] = (sigma2_val ** (-alpha - 1)) * np.exp(-beta / sigma2_val) * \
            #                    norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))
            pdf_values[i, j] = invgamma.pdf(sigma2_val, alpha, beta) * norm.pdf(mu_val, mu_0, np.sqrt(sigma2_val / lambda_))

    
    # Plot the PDF values
    plt.figure(figsize=(10, 8))
    cp = plt.contourf(mu, sigma2, pdf_values, levels=50, cmap='viridis')
    plt.colorbar(cp)
    plt.xlabel('Mean (mu)')
    plt.ylabel('Variance (sigma^2)')
    plt.title('Normal-Inverse Gamma Distribution PDF')
    plt.show()
# Out:
# [4.2653027] [1.2053325] [4.508124] [0.02347793]
# [0.00555237]

# %%
dist_colors = ['g', 'y']
for i,d in enumerate([3.]):
    mu_0, lambda_, alpha, beta = [x.detach().numpy() for x in certain_model(torch.tensor([d]))]
    print(mu_0, lambda_, alpha, beta)
    print("E[mu]: ",mu_0)
    print("Var[mu]: ",(beta / ((alpha-1)*lambda_)))
    print("E[sigma]: ",(beta / (alpha-1)))
    print("E[sigma] / lambda: ",(beta / (alpha-1)) / lambda_)
    
    num_dist_samples = 1000
    l = np.linspace(-20, 20, 100)
    mu_list = list()
    sigma_list = list()
    msv_list = list()
    for _ in range(num_dist_samples):
        sigma2_sample = invgamma.rvs(alpha, beta)
        mu_sample = norm.rvs(mu_0, np.sqrt(sigma2_sample / lambda_))
        msv_list.append(np.sqrt(sigma2_sample / lambda_))
        mu_list.append(mu_sample)
        sigma_list.append(sigma2_sample / lambda_)
        plt.plot(l, norm.pdf(l, mu_sample, sigma2_sample), alpha=0.1, color=dist_colors[i])
    print("diff min: ",max(mu_list) - min(mu_list))
    print(min(sigma_list), max(sigma_list))
    print("msv: ",np.array(msv_list).mean())
    plt.xlim(-25,25)
    plt.ylim(-0.1,4)
    print()
    
plt.show()
# Out:
# [4.2653027] [1.2053325] [4.508124] [0.02347793]
# E[mu]:  [4.2653027]
# Var[mu]:  [0.00555237]
# E[sigma]:  [0.00669245]
# E[sigma] / lambda:  [0.00555237]
# diff min:  4.224239255890595
# [0.07188298] [1.7078456]
# msv:  0.49908996

# %%
from scipy.stats import t
l = np.linspace(-20, 20, 100)
epsilon = 0.95

mu_0, lambda_, alpha, beta = 4.331047, 10.395155, 5.679753, 0.06286594
t_dist = t((2*alpha), mu_0, ((beta*(1+lambda_))/(lambda_*alpha))**(1/2))
plt.plot(l, t_dist.pdf(l), label='model 1')
nu = 2 * alpha
num_sample = nu + 1

st_cvar =         mu_0 + ((beta * (1+lambda_))/(lambda_*alpha))**(1/2) * ((2*alpha+t.ppf(epsilon, nu)**2)/((2*alpha-1)*(1-epsilon))) * t.pdf(t.ppf(epsilon, nu), nu)
plt.axvline(x=st_cvar, color='r', linestyle='--', label=f'model 1 CVaR (α={epsilon*100}%) = {st_cvar:.2f}')

plt.xlim(-20,20)
plt.legend()
plt.show()

# %%
from scipy.stats import t
l = np.linspace(-20, 20, 100)
epsilon = 0.95

mu_0, lambda_, alpha, beta = 4.2653027, 1.2053325, 4.508124, 0.02347793
t_dist = t((2*alpha), mu_0, ((beta*(1+lambda_))/(lambda_*alpha))**(1/2))
plt.plot(l, t_dist.pdf(l), label='model 2')
nu = 2 * alpha
num_sample = nu + 1

st_cvar =         mu_0 + ((beta * (1+lambda_))/(lambda_*alpha))**(1/2) * ((2*alpha+t.ppf(epsilon, nu)**2)/((2*alpha-1)*(1-epsilon))) * t.pdf(t.ppf(epsilon, nu), nu)
plt.axvline(x=st_cvar, color='r', linestyle='--', label=f'model 2 CVaR (α={epsilon*100}%) = {st_cvar:.2f}')

plt.xlim(-20,20)
plt.legend()
plt.show()

# %%
from scipy.stats import t
l = np.linspace(1, 6, 100)
epsilon = 0.95

mu_0, lambda_, alpha, beta = 3.3069992, 0.09277739, 3.4838414, 0.03017405
t_dist = t((2*alpha), mu_0, (beta*(1+lambda_))/(lambda_*alpha))
plt.plot(l, t_dist.pdf(l), label='uncertain')
st_cvar = mu_0 + (beta * (1+lambda_))/(lambda_*alpha) * ((2*alpha+t_dist.ppf(epsilon)**2)/(2*alpha-1)*(1-epsilon)) * t_dist.pdf(t_dist.ppf(epsilon))
print(st_cvar)
plt.axvline(x=st_cvar, color='r', linestyle='--', label=f'uncertain CVaR (α={epsilon*100}%) = {st_cvar:.2f}')

ale = beta / ((alpha-1))
norm_dist = norm(mu_0, ale)
plt.plot(l, norm_dist.pdf(l))

mu_0, lambda_, alpha, beta = 4.9552536, 6.7182527, 5.0919623, 0.03772904
t_dist = t((2*alpha), mu_0, (beta*(1+lambda_))/(lambda_*alpha))
plt.plot(l, t_dist.pdf(l), label='certain')
st_cvar = mu_0 + (beta * (1+lambda_))/(lambda_*alpha) * ((2*alpha+t_dist.ppf(epsilon)**2)/(2*alpha-1)*(1-epsilon)) * t_dist.pdf(t_dist.ppf(epsilon))
print(st_cvar)
plt.axvline(x=st_cvar, color='g', linestyle='--', label=f'certain CVaR (α={epsilon*100}%) = {st_cvar:.2f}')

plt.legend()
plt.xlim(0,7)
ale = beta / ((alpha-1))
norm_dist = norm(mu_0, ale)
# plt.plot(l, norm_dist.pdf(l))
# Out:
# 3.3188181116583153
# 4.970817731641539

# %%
l = np.linspace(-10,30)
mu = 1
sigma = 2
nu = 3
epsilon=0.95
st_dist = t(nu, mu, sigma)
norm_dist = norm(mu, sigma)
plt.plot(l, st_dist.pdf(l), label='student t')
plt.plot(l, norm_dist.pdf(l), label='norm')
cvar = mu + sigma * norm_dist.pdf(norm_dist.ppf(epsilon))/(1-epsilon)
st_cvar = mu + sigma * ((nu+st_dist.ppf(epsilon)**2)/((nu-1)*(1-epsilon))) * st_dist.pdf(st_dist.ppf(epsilon))
plt.axvline(x=cvar, color='orange', linestyle='--')
plt.axvline(x=st_cvar, color='blue', linestyle='--')
plt.legend()

# %%
l = np.linspace(0,10)
plt.plot(l, norm(1, 0.01).pdf(l))
print(norm(3, 0.01).cdf(2.1))
plt.show()
# Out:
# 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# x축 데이터 생성
x = np.linspace(-10, 10, 1000)

# 평균과 표준편차 설정
mu1, sigma = 0, 0.01
mu2 = 5

# 정규분포 생성
pdf1 = norm.pdf(x, mu1, sigma)
pdf2 = norm.pdf(x, mu2, sigma)

# 그래프 그리기
plt.plot(x, pdf1, label=f"Mean = {mu1}")
plt.plot(x, pdf2, label=f"Mean = {mu2}")
plt.legend()
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.title("PDF of Normal Distributions with Different Means")
plt.show()
